# %%
import subprocess
import tempfile
import os
import sys
from collections import defaultdict
from typing import Union

class Miner:
    def __init__(self, miner_path="./miner", base_file_name: Union[None, str] = None, verbose: bool = False):
        self.miner_path = miner_path
        self.verbose = verbose
        self.base_file_name = tempfile.mktemp() if not base_file_name else base_file_name
        self.input_file_name = self.base_file_name + "_input"
        self.substructure_file_name = self.base_file_name + "_output.txt"
        self.identifiers_file_name = self.base_file_name + "_ids.txt"


    def runButCooler(self, x: list[str], **kwargs):
        self.save_input_to_file(x)
        command = self.build_command(**kwargs)
        success = self.run_miner(command)
        if success is True:
            result = self.parse_output_but_cooler()
            return result

    def save_input_to_file(self, x: list[str]) -> None:
        with open(self.input_file_name, 'w') as input_file:
            for smile in x:
                line = f"{smile},0,{smile}\n"
                input_file.write(line)

    def build_command(self, **kwargs) -> list[str]:
        command = [self.miner_path, self.input_file_name]
        for key, value in kwargs.items():
            if isinstance(value, bool):
                if value:
                    command.append(f"-{key}")
            else:
                command.append(f"-{key}{value}")

        command.append(self.substructure_file_name)
        command.append(self.identifiers_file_name)

        return command

    def run_miner(self, command: list[str]) -> bool:
        try:
            result = subprocess.run(command, capture_output=self.verbose, text=True)
            result.check_returncode()

        except subprocess.CalledProcessError as e:
            print("Error running MoSS:", e.stderr)
            return False
        except Exception as e:
            print("An error occurred:", str(e))
            return False
        return True

    def parse_output_but_cooler(self) -> dict[str, list[str]]:
        result = defaultdict(list)
        with open(self.substructure_file_name, "r") as substructure_file, open(self.identifiers_file_name, "r") as identifiers_file:
            substucture_lines = substructure_file.read().strip().split("\n")[1:]
            molecular_lines = identifiers_file.read().strip().split("\n")[1:]

            assert(len(substucture_lines) == len(molecular_lines))

            for substructure_line, molecular_line in zip(substucture_lines, molecular_lines):
                entities = molecular_line.split(':')[1].split(',')
                smile = substructure_line.split(',')[1]
                for entity in entities:
                    result[entity].append(smile)

        return dict(result)






    def run(self, input_file, output_file=None, **kwargs):
        # Build the command with the provided arguments
        command = [self.miner_path, input_file]

        # Add additional command-line arguments
        for key, value in kwargs.items():
            if isinstance(value, bool):
                if value:
                    command.append(f"-{key}")
            else:
                command.append(f"-{key}{value}")

        # Add the output file if specified
        base_file_name = tempfile.mktemp() if not output_file else output_file
        substructure_file_name = base_file_name + "_output.txt"
        identifiers_file_name = base_file_name + "_ids.txt"

        command.append(substructure_file_name)
        command.append(identifiers_file_name)

        output = None
        try:
            # Run the command and capture the output
            # print(f"command being executed: {command}")
            result = subprocess.run(command, capture_output=True, text=True)
            result.check_returncode()  # Raise an error if the command failed

            # Read and parse the output file
            with open(substructure_file_name, "r") as substructure_file, open(identifiers_file_name, "r") as identifiers_file:
                output = self.parse_output(substructure_file.read(), identifiers_file.read()) # TODO refactor this somehow


        except subprocess.CalledProcessError as e:
            print("Error running MoSS:", e.stderr)
        except Exception as e:
            print("An error occurred:", str(e))
        finally:
            if not output_file and os.path.exists(substructure_file_name):
                os.remove(substructure_file_name)

            return output



    def parse_output(self, substucture_data, molecular_id_data):
        result = defaultdict(list)
        substucture_lines = substucture_data.strip().split("\n")[1:]
        molecular_lines = molecular_id_data.strip().split("\n")[1:]

        assert(len(substucture_lines) == len(molecular_lines))

        for substructure_line, molecular_line in zip(substucture_lines, molecular_lines):
            entities = molecular_line.split(':')[1].split(',')
            smile = substructure_line.split(',')[1]
            for entity in entities:
                result[entity].append(smile)

        return dict(result)

# %%
from skfp.datasets.moleculenet import load_bace
from skfp.model_selection import scaffold_train_test_split
smiles_list, y = load_bace()
mols_train, mols_test, y_train, y_test = scaffold_train_test_split(smiles_list, y, test_size=0.2)

# %%
len(mols_train)
# Out:
# 1210

# %%
miner = Miner(base_file_name="test")
results = miner.runButCooler(mols_train, jS=True, s=5)
# Out:
# moss.Miner - molecular substructure miner (MoSS)
# version 8.3 (2022.11.19)    (c) 2002-2022 Christian Borgelt
# parsing seed description ... [1 atom(s), 0 bond(s)] done.
# parsing excluded atom types ... [1 atom(s)] done.
# reading molecules ... [1210 (1210+0) molecule(s)] done [0.013s].
# marking bridges ... [1210 molecule(s)] done [0.001s].
# masking atom and bond types ... [1210 molecule(s)] done [0.001s].
# preparing/recoding molecules ... [1210 molecule(s)] done [0.002s].
# embedding the seed ... [1210 (380+0) molecule(s)] done [0.0s].
# searching for substructures ... [361 substructure(s)] done [4.226s].
# search statistics:
# maximum search tree height   : 30
# number of search tree nodes  : 37793
# number of created fragments  : 146943
# number of created embeddings : 27292135
# insufficient support pruning : 105409
# perfect extension pruning    : 2830
# equivalent sibling pruning   : 0
# canonical form pruning       : 279
# ring order pruning           : 0
# duplicate fragment pruning   : 0
# non-closed fragments         : 37432
# fragments with open rings    : 0
# fragments with invalid chains: 0
# auxiliary invalid fragments  : 0
# accesses to repository       : 0
# comparisons with fragments   : 0
# actual isomorphism tests     : 0
# comparisons with embeddings  : 0

# %%
xdata = zip(mols_train, y_train)

y_train_new = [y for x, y in xdata if x in results.keys()]

len(y_train_new)
# Out:
# 380

# %%
len(results.keys())
# Out:
# 380

# %%
y_train = y_train_new

# %%
from sklearn.preprocessing import MultiLabelBinarizer

vocabulary = list(set([substructure for x in results.values() for substructure in x]))

mlb = MultiLabelBinarizer(classes=vocabulary)
mlb.fit(vocabulary)

results_transformed = {key: mlb.transform([value])[0] for key, value in results.items()}

# %%
test_results = miner.runButCooler(mols_test, jS=True, s=5)
test_results_transformed = {key: mlb.transform([value])[0] for key, value in test_results.items()}
# Out:
# moss.Miner - molecular substructure miner (MoSS)
# version 8.3 (2022.11.19)    (c) 2002-2022 Christian Borgelt
# parsing seed description ... [1 atom(s), 0 bond(s)] done.
# parsing excluded atom types ... [1 atom(s)] done.
# reading molecules ... [303 (303+0) molecule(s)] done [0.003s].
# marking bridges ... [303 molecule(s)] done [0.0s].
# masking atom and bond types ... [303 molecule(s)] done [0.001s].
# preparing/recoding molecules ... [303 molecule(s)] done [0.0s].
# embedding the seed ... [303 (109+0) molecule(s)] done [0.0s].
# searching for substructures ... [251 substructure(s)] done [0.459s].
# search statistics:
# maximum search tree height   : 30
# number of search tree nodes  : 14728
# number of created fragments  : 45286
# number of created embeddings : 2455590
# insufficient support pruning : 30057
# perfect extension pruning    : 165
# equivalent sibling pruning   : 0
# canonical form pruning       : 284
# ring order pruning           : 0
# duplicate fragment pruning   : 0
# non-closed fragments         : 14477
# fragments with open rings    : 0
# fragments with invalid chains: 0
# auxiliary invalid fragments  : 0
# accesses to repository       : 0
# comparisons with fragments   : 0
# actual isomorphism tests     : 0
# comparisons with embeddings  : 0

# %%
y_test_new = [y for x, y in zip(mols_test, y_test) if x in test_results.keys()]
y_test = y_test_new

# %%
results
# Out:
# {'S(=O)(=O)(N(C)c1cc(cc(c1)C(=O)NC(C)c1ccc(F)cc1)-c1nc([nH]n1)C([NH3+])(Cc1ccccc1)C)C': ['S(-N(-c1:c:c(-C):c:c(-C(-N-C(-C)-C)=O):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C):c:c(-C(-N-C(-C)-C)=O):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C):c):c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c):c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c)-C)(-C)(=O)=O',
#   'S(-N(-C)-C)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C):c:c(-C-N-C-C):c:1)(-C)(=O)=O',
#   'S(-N-c(:c:c-C):c:c(-C-N-C-C):c)(-C)(=O)=O',
#   'S(-N-c(:c:c(-C):c):c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C-N-C-C):c:1)(-C)(=O)=O',
#   'S(-N-c(:c:c):c:c-C(-N-C(-C)-C)=O)(-C)(=O)=O',
#   'S(-N-c(:c:c):c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c1:c:c:c:c:c:1)(-C)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C)-C)=O):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c(-C-N-C-C):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C)=O)(-C)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C)=O)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c)(-C)(=O)=O',
#   'S(-N-C)(-C)(=O)=O',
#   'S(-N)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)-C)(=O)=O',
#   'S(-N(-c(:c:c):c:c-C(-N-C(-C)-C)=O)-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c:c:1)-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C)=O):c:c)-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C)=O)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C)=O)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c)-C)(=O)=O',
#   'S(-N(-C)-C)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C-N-C-C):c:1)(=O)=O',
#   'S(-N-c(:c:c):c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c(:c:c):c:c-C-N-C-C)(=O)=O',
#   'S(-N-c1:c:c:c:c:c:1)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C)-C)=O):c:c)(=O)=O',
#   'S(-N-c:c:c(-C-N-C-C):c:c)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c)(=O)=O',
#   'S(-N-C)(=O)=O',
#   'S(-N)(=O)=O',
#   'S(-C)(=O)=O',
#   'S(-C)=O',
#   'S-C',
#   'S(=O)=O',
#   'S=O',
#   'S'],
#  'S(=O)(=O)(N(C)c1cc(cc(c1)C(=O)NC)C(=O)NC(C(O)CC(C(=O)NC(C(C)C)C(=O)NCc1ccccc1)C)COCc1cc(F)cc(F)c1)C': ['S(-N(-c1:c:c(-C):c:c(-C(-N-C(-C)-C)=O):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C-C-C)=O):c:c(-C):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C-N-C-C-C):c:c(-C):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C(-C)-C(-C)-O)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C(-C-C)-C-O)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C(-C)-C-C)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C):c:c(-C(-N-C(-C)-C)=O):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C-C(-C)-O)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C-C-C)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C-N-C-C-C):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C(-C)-O)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C-C)-C-O)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C-C)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C):c):c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C(-C)-O)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C-C)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C-N-C-C-C):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C(-C)-C(-C)-O)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C(-C-C)-C-O)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C(-C)-C-C)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C-C(-C)-O)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C-C-C)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C-N-C-C-C):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C(-C)-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C-C)-C-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c):c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C(-C)-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C-N-C-C-C):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C(-C)-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C-C)-C-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C-C(-C)-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C-C-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C-N-C-C-C):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C(-C)-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C-C)-C-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C-C(-C)-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C-C-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C-N-C-C-C)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C(-C)-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C-C)-C-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C-C(-C)-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C-C-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C-N-C-C-C)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c)-C)(-C)(=O)=O',
#   'S(-N(-C)-C)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C-N-C-C-C):c:c(-C):c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C):c:c(-C-N-C-C):c:1)(-C)(=O)=O',
#   'S(-N-c(:c:c(-C-N-C-C(-C)-O):c):c:c-C)(-C)(=O)=O',
#   'S(-N-c(:c:c(-C-N-C-C-C):c):c:c-C)(-C)(=O)=O',
#   'S(-N-c(:c:c-C):c:c(-C-N-C-C):c)(-C)(=O)=O',
#   'S(-N-c(:c:c-C-N-C-C(-C)-O):c:c(-C):c)(-C)(=O)=O',
#   'S(-N-c(:c:c-C-N-C-C-C):c:c(-C):c)(-C)(=O)=O',
#   'S(-N-c(:c:c(-C):c):c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C(-N-C(-C)-C(-C)-O)=O):c:c:c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C(-N-C(-C-C)-C-O)=O):c:c:c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C(-N-C(-C)-C-C)=O):c:c:c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C(-N-C-C(-C)-O)=O):c:c:c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C(-N-C-C-C)=O):c:c:c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C-N-C-C(-C)-O):c:c:c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C-N-C-C-C):c:c:c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C-N-C-C):c:1)(-C)(=O)=O',
#   'S(-N-c(:c:c-C(-N-C(-C)-C(-C)-O)=O):c:c)(-C)(=O)=O',
#   'S(-N-c(:c:c-C(-N-C(-C-C)-C-O)=O):c:c)(-C)(=O)=O',
#   'S(-N-c(:c:c-C(-N-C(-C)-C-C)=O):c:c)(-C)(=O)=O',
#   'S(-N-c(:c:c):c:c-C(-N-C(-C)-C)=O)(-C)(=O)=O',
#   'S(-N-c(:c:c-C(-N-C-C(-C)-O)=O):c:c)(-C)(=O)=O',
#   'S(-N-c(:c:c-C(-N-C-C-C)=O):c:c)(-C)(=O)=O',
#   'S(-N-c(:c:c-C-N-C-C(-C)-O):c:c)(-C)(=O)=O',
#   'S(-N-c(:c:c-C-N-C-C-C):c:c)(-C)(=O)=O',
#   'S(-N-c(:c:c):c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c1:c:c:c:c:c:1)(-C)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C)-C(-C)-O)=O):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C-C)-C-O)=O):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C)-C-C)=O):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C)-C)=O):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C-C(-C)-O)=O):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C-C-C)=O):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c(-C-N-C-C(-C)-O):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c(-C-N-C-C-C):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c(-C-N-C-C):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C(-C)-O)=O)(-C)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C-C)-C-O)=O)(-C)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C-C)=O)(-C)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C)=O)(-C)(=O)=O',
#   'S(-N-c:c:c-C(-N-C-C(-C)-O)=O)(-C)(=O)=O',
#   'S(-N-c:c:c-C(-N-C-C-C)=O)(-C)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C(-C)-O)(-C)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C-C)(-C)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C(-C)-O)=O)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C-C)-C-O)=O)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C-C)=O)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C)=O)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C-C(-C)-O)=O)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C-C-C)=O)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C(-C)-O)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C-C)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c)(-C)(=O)=O',
#   'S(-N-C)(-C)(=O)=O',
#   'S(-N)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C(-C)-C(-C)-O)=O):c:c:c:1)-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C(-C-C)-C-O)=O):c:c:c:1)-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C(-C)-C-C)=O):c:c:c:1)-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C-C(-C)-O)=O):c:c:c:1)-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C-C-C)=O):c:c:c:1)-C)(=O)=O',
#   'S(-N(-c1:c:c(-C-N-C-C-C):c:c:c:1)-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C(-C)-O)=O):c:c)-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C-C)-C-O)=O):c:c)-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C-C)=O):c:c)-C)(=O)=O',
#   'S(-N(-c(:c:c):c:c-C(-N-C(-C)-C)=O)-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C(-C)-O)=O):c:c)-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C-C)=O):c:c)-C)(=O)=O',
#   'S(-N(-c(:c:c-C-N-C-C-C):c:c)-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c:c:1)-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C(-C)-O)=O):c:c)-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C-C)-C-O)=O):c:c)-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C-C)=O):c:c)-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C)=O):c:c)-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C-C(-C)-O)=O):c:c)-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C-C-C)=O):c:c)-C)(=O)=O',
#   'S(-N(-c:c:c(-C-N-C-C-C):c:c)-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C(-C)-O)=O)-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C-C)-C-O)=O)-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C-C)=O)-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C)=O)-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C-C(-C)-O)=O)-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C-C-C)=O)-C)(=O)=O',
#   'S(-N(-c:c:c-C-N-C-C-C)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C(-C)-O)=O)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C-C)-C-O)=O)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C-C)=O)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C)=O)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C-C(-C)-O)=O)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C-C-C)=O)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C-N-C-C-C)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c)-C)(=O)=O',
#   'S(-N(-C)-C)(=O)=O',
#   'S(-N-c1:c:c(-C(-N-C(-C)-C(-C)-O)=O):c:c:c:1)(=O)=O',
#   'S(-N-c1:c:c(-C(-N-C(-C-C)-C-O)=O):c:c:c:1)(=O)=O',
#   'S(-N-c1:c:c(-C(-N-C(-C)-C-C)=O):c:c:c:1)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)(=O)=O',
#   'S(-N-c1:c:c(-C(-N-C-C(-C)-O)=O):c:c:c:1)(=O)=O',
#   'S(-N-c1:c:c(-C(-N-C-C-C)=O):c:c:c:1)(=O)=O',
#   'S(-N-c1:c:c(-C-N-C-C(-C)-O):c:c:c:1)(=O)=O',
#   'S(-N-c1:c:c(-C-N-C-C-C):c:c:c:1)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C-N-C-C):c:1)(=O)=O',
#   'S(-N-c(:c:c-C(-N-C(-C)-C(-C)-O)=O):c:c)(=O)=O',
#   'S(-N-c(:c:c-C(-N-C(-C-C)-C-O)=O):c:c)(=O)=O',
#   'S(-N-c(:c:c-C(-N-C(-C)-C-C)=O):c:c)(=O)=O',
#   'S(-N-c(:c:c):c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c(:c:c-C(-N-C-C(-C)-O)=O):c:c)(=O)=O',
#   'S(-N-c(:c:c-C(-N-C-C-C)=O):c:c)(=O)=O',
#   'S(-N-c(:c:c-C-N-C-C(-C)-O):c:c)(=O)=O',
#   'S(-N-c(:c:c-C-N-C-C-C):c:c)(=O)=O',
#   'S(-N-c(:c:c):c:c-C-N-C-C)(=O)=O',
#   'S(-N-c1:c:c:c:c:c:1)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C)-C(-C)-O)=O):c:c)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C-C)-C-O)=O):c:c)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C)-C-C)=O):c:c)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C)-C)=O):c:c)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C-C(-C)-O)=O):c:c)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C-C-C)=O):c:c)(=O)=O',
#   'S(-N-c:c:c(-C-N-C-C(-C)-O):c:c)(=O)=O',
#   'S(-N-c:c:c(-C-N-C-C-C):c:c)(=O)=O',
#   'S(-N-c:c:c(-C-N-C-C):c:c)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C(-C)-O)=O)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C-C)-C-O)=O)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C-C)=O)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c:c:c-C(-N-C-C(-C)-O)=O)(=O)=O',
#   'S(-N-c:c:c-C(-N-C-C-C)=O)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C(-C)-O)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C-C)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C(-C)-O)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C-C)-C-O)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C-C)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C-C(-C)-O)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C-C-C)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C(-C)-O)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c)(=O)=O',
#   'S(-N-C)(=O)=O',
#   'S(-N)(=O)=O',
#   'S(-C)(=O)=O',
#   'S(-C)=O',
#   'S-C',
#   'S(=O)=O',
#   'S=O',
#   'S'],
#  'S(=O)(=O)(N(C)c1cc(cc(c1)C(=O)NC(C)c1ccc(F)cc1)-c1onc(n1)C([NH3+])(Cc1ccccc1)C)C': ['S(-N(-c1:c:c(-C):c:c(-C(-N-C(-C)-C)=O):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C):c:c(-C(-N-C(-C)-C)=O):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C):c):c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c):c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c)-C)(-C)(=O)=O',
#   'S(-N(-C)-C)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C):c:c(-C-N-C-C):c:1)(-C)(=O)=O',
#   'S(-N-c(:c:c-C):c:c(-C-N-C-C):c)(-C)(=O)=O',
#   'S(-N-c(:c:c(-C):c):c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C-N-C-C):c:1)(-C)(=O)=O',
#   'S(-N-c(:c:c):c:c-C(-N-C(-C)-C)=O)(-C)(=O)=O',
#   'S(-N-c(:c:c):c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c1:c:c:c:c:c:1)(-C)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C)-C)=O):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c(-C-N-C-C):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C)=O)(-C)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C)=O)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c)(-C)(=O)=O',
#   'S(-N-C)(-C)(=O)=O',
#   'S(-N)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)-C)(=O)=O',
#   'S(-N(-c(:c:c):c:c-C(-N-C(-C)-C)=O)-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c:c:1)-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C)=O):c:c)-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C)=O)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C)=O)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c)-C)(=O)=O',
#   'S(-N(-C)-C)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C-N-C-C):c:1)(=O)=O',
#   'S(-N-c(:c:c):c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c(:c:c):c:c-C-N-C-C)(=O)=O',
#   'S(-N-c1:c:c:c:c:c:1)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C)-C)=O):c:c)(=O)=O',
#   'S(-N-c:c:c(-C-N-C-C):c:c)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-
(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C(-C)-O)=O)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C-C)-C-O)=O)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C-C)=O)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c:c:c-C(-N-C-C(-C)-O)=O)(=O)=O',
#   'S(-N-c:c:c-C(-N-C-C-C)=O)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C(-C)-O)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C-C)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C(-C)-O)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C-C)-C-O)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C-C)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C-C(-C)-O)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C-C-C)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C(-C)-O)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c)(=O)=O',
#   'S(-N-C)(=O)=O',
#   'S(-N)(=O)=O',
#   'S(-C)(=O)=O',
#   'S(-C)=O',
#   'S-C',
#   'S(=O)=O',
#   'S=O',
#   'S'],
#  'S(=O)(=O)(N(C)c1cc(cc(c1)C(=O)NC(C)c1ccc(F)cc1)-c1nc(on1)C([NH3+])(Cc1ccccc1)C)C': ['S(-N(-c1:c:c(-C):c:c(-C(-N-C(-C)-C)=O):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C):c:c(-C(-N-C(-C)-C)=O):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C):c):c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c):c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c)-C)(-C)(=O)=O',
#   'S(-N(-C)-C)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C):c:c(-C-N-C-C):c:1)(-C)(=O)=O',
#   'S(-N-c(:c:c-C):c:c(-C-N-C-C):c)(-C)(=O)=O',
#   'S(-N-c(:c:c(-C):c):c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C-N-C-C):c:1)(-C)(=O)=O',
#   'S(-N-c(:c:c):c:c-C(-N-C(-C)-C)=O)(-C)(=O)=O',
#   'S(-N-c(:c:c):c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c1:c:c:c:c:c:1)(-C)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C)-C)=O):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c(-C-N-C-C):c:c)(-C)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C)=O)(-C)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C)=O)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C)(-C)(=O)=O',
#   'S(-N-c:c:c:c:c)(-C)(=O)=O',
#   'S(-N-C)(-C)(=O)=O',
#   'S(-N)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)-C)(=O)=O',
#   'S(-N(-c(:c:c):c:c-C(-N-C(-C)-C)=O)-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c:c:1)-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C)=O):c:c)-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C)=O)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C)=O)-C)(=O)=O',
#   'S(-N(-c:c:c:c:c)-C)(=O)=O',
#   'S(-N(-C)-C)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)(=O)=O',
#   'S(-N-c1:c:c:c:c(-C-N-C-C):c:1)(=O)=O',
#   'S(-N-c(:c:c):c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c(:c:c):c:c-C-N-C-C)(=O)=O',
#   'S(-N-c1:c:c:c:c:c:1)(=O)=O',
#   'S(-N-c:c:c(-C(-N-C(-C)-C)=O):c:c)(=O)=O',
#   'S(-N-c:c:c(-C-N-C-C):c:c)(=O)=O',
#   'S(-N-c:c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c:c:c-C-N-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C(-N-C(-C)-C)=O)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c)(=O)=O',
#   'S(-N-C)(=O)=O',
#   'S(-N)(=O)=O',
#   'S(-C)(=O)=O',
#   'S(-C)=O',
#   'S-C',
#   'S(=O)=O',
#   'S=O',
#   'S'],
#  'S(=O)(=O)(N(C)c1cc(cc(c1)C(=O)NC(C(O)CC(OC)COc1ccccc1)COc1cc(F)cc(F)c1)C(=O)NC(C)c1ccccc1)C': ['S(-N(-c1:c:c(-C):c:c(-C(-N-C(-C)-C)=O):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C-C-C)=O):c:c(-C):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C-N-C-C-C):c:c(-C):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C(-C)-C(-C)-O)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C(-C-C)-C-O)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C(-C)-C-C)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C):c:c(-C(-N-C(-C)-C)=O):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C-C(-C)-O)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C-C-C)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C-N-C-C-C):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C(-C)-O)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C-C)-C-O)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C-C)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C):c):c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C(-C)-O)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C-C)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C-N-C-C-C):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C(-C)-C(-C)-O)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C(-C-C)-C-O)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C(-C)-C-C)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C-C(-C)-O)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C-C-C)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C-N-C-C-C):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C(-C)-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C-C)-C-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c):c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C(-C)-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C-N-C-C-C):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C(-C)-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C-C)-C-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C-C(-C)-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C-C-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C-N-C-C-C):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C(-C)-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C-C)-C-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C-C(-C)-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C-C-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C-N-C-C-C)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C(-C)-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C-C)-C-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C-C(-C)-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C(-N-C-C-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c-C-N-C-C-C)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c:c:c)-C)(-C)(=O)=O',
#   'S(-N(-C)-C)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C-N-C-C-C):c:c(-C):c:1)(-C)(=O)=O',
#   'S(-N-c1:c:c(-C):c:c(-C-N-C-C):c:1)(-C)(=O)=O',
#   'S(-N-c(:c:c(-C-N-C-C(-C)-O):c):c:c-C)(-C)(=O)=O',
#   'S(-N-c(:c:c(-C-N-C-C-C):c):c:c-C)(-C)(=O)=O',
#   'S(-N-c(:c:c-C):c:c(-C-N-C-C):c)(-C)(=O)=O',
#   'S(-N-c(:c:c-C-N-C-
(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c-C-N-C-C)(=O)=O',
#   'S(-N-c:c:c:c:c)(=O)=O',
#   'S(-N-C)(=O)=O',
#   'S(-N)(=O)=O',
#   'S(-C)(=O)=O',
#   'S(-C)=O',
#   'S-C',
#   'S(=O)=O',
#   'S=O',
#   'S'],
#  'S(=O)(=O)(N(C)c1cc(cc(c1)C(=O)NC(C(O)CC(C(=O)NC1CC1)C)COCc1cc(F)cc(F)c1)C(=O)NC(C)c1ccccc1)C': ['S(-N(-c1:c:c(-C):c:c(-C(-N-C(-C)-C)=O):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C-C-C)=O):c:c(-C):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C-N-C-C-C):c:c(-C):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C(-C)-C(-C)-O)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C(-C-C)-C-O)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C(-C)-C-C)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C):c:c(-C(-N-C(-C)-C)=O):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C-C(-C)-O)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C(-N-C-C-C)=O):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C-N-C-C-C):c):c:c-C)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C(-C)-O)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C-C)-C-O)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C-C)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c(-C):c):c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C(-C)-O)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C-C)=O):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C-N-C-C-C):c:c(-C):c)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C(-C)-C(-C)-O)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C(-C-C)-C-O)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C(-C)-C-C)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c(-C(-N-C(-C)-C)=O):c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C-C(-C)-O)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C(-N-C-C-C)=O):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c(-C-N-C-C-C):c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C(-C)-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C-C)-C-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C(-C)-C-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c):c:c-C(-N-C(-C)-C)=O)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C(-C)-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C(-N-C-C-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c(:c:c-C-N-C-C-C):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c1:c:c:c:c:c:1)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C(-C)-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C-C)-C-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C(-C)-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C-C(-C)-O)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C(-N-C-C-C)=O):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c(-C-N-C-C-C):c:c)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C(-C)-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C-C)-C-O)=O)-C)(-C)(=O)=O',
#   'S(-N(-c:c:c-C(-N-C(-C)-C-C)=O)-C)(-C)(=O)=O',
# ...
#   'S(-C)(-C)=O',
#   'S(-C-C(-C)-N)-C-C',
#   'S(-C-C(-C)-C)-C-C-N',
#   'S(-C-C-N)-C-C',
#   'S(-C-C-C)-C-C',
#   'S(-C-C)-C-C',
#   'S(-C-C(-N)-C-C-C-c1:c:c:c:c:c:1)-C',
#   'S(-C-C(-N)-C-C-C)-C',
#   'S(-C-C(-C)-N)-C',
#   'S(-C-C-N)-C',
#   'S(-C-C(-C)-C-c1:c:c:c:c:c:1)-C',
#   'S(-C-C(-C)-C-C)-C',
#   'S(-C-C(-C)-C)-C',
#   'S(-C-C-C-C-N)-C',
#   'S(-C-C-C-C-C-c1:c:c:c:c:c:1)-C',
#   'S(-C-C-C-C-C-C)-C',
#   'S(-C-C-C-C-C)-C',
#   'S(-C-C-C-c1:c:c:c:c:c:1)-C',
#   'S(-C-C-C-c:c:c:c:c)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S(-C-C-N)=O',
#   'S(-C-C-C-C(-C)-N)=O',
#   'S(-C-C-C-C-N)=O',
#   'S(-C-C-C-C(-C-C)-C)=O',
#   'S(-C-C-C-c1:c:c:c:c:c:1)=O',
#   'S(-C-C-C-C)=O',
#   'S(-C-C-C)=O',
#   'S(-C-C)=O',
#   'S(-C)=O',
#   'S-C-C(-N)-C-C(-C)-C-c1:c:c:c:c:c:1',
#   'S-C-C-N',
#   'S-C-C(-C)-C-C-C',
#   'S-C-C-C-C(-N)-C',
#   'S-C-C-C-C-N',
#   'S-C-C-C-C(-C)-C-C',
#   'S-C-C-C-C(-C)-C',
#   'S-C-C-C-c1:c:c:c:c:c:1',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S=O',
#   'S'],
#  'S1CC(N=C(N)C1)(C)c1cc(ccc1)-c1cc(OC)ccc1': ['S(-C-C(-C)-N)-C-C',
#   'S(-C-C(-C)-C)-C-C-N',
#   'S(-C-C-N)-C-C',
#   'S(-C-C-C)-C-C',
#   'S(-C-C)-C-C',
#   'S(-C-C(-C)-N)-C',
#   'S(-C-C-N)-C',
#   'S(-C-C(-C)-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-N',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S1CC(=NC1(c1cc(ccc1)-c1cccnc1)c1ccc(OC)cc1)N': ['S(-C-C-N)-C-C',
#   'S(-C-C)-C-C',
#   'S(-C-C-N)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-N',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S1CC(=NC1(C)c1cc(ccc1)-c1cc(OC)ccc1)N': ['S(-C-C-N)-C-C',
#   'S(-C-C)-C-C',
#   'S(-C-C-N)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-N',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S1CCC(=NC1(C)c1cc(ccc1)-c1cc(OC)ccc1)N': ['S(-C-C-C)-C-C',
#   'S(-C-C)-C-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S1CCC(=NC1(C)c1cc(ccc1)-c1cncnc1)N': ['S(-C-C-C)-C-C',
#   'S(-C-C)-C-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'Clc1cc(cnc1)-c1cc2c(CC(CC23N=C(SC3)N)(C)C)cc1': ['S(-C-C(-N)-C-C-C-c1:c:c:c:c:c:1)-C',
#   'S(-C-C(-N)-C-C-C)-C',
#   'S(-C-C(-C)-N)-C',
#   'S(-C-C-N)-C',
#   'S(-C-C(-C)-C-C)-C',
#   'S(-C-C(-C)-C)-C',
#   'S(-C-C-C-C-C-c1:c:c:c:c:c:1)-C',
#   'S(-C-C-C-C-C-C)-C',
#   'S(-C-C-C-C-C)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C(-N)-C-C(-C)-C-c1:c:c:c:c:c:1',
#   'S-C-C-N',
#   'S-C-C(-C)-C-C-C',
#   'S-C-C-C-C(-C)-C-C',
#   'S-C-C-C-C(-C)-C',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'Clc1ccc(nc1)C(=O)Nc1cc2c(CCC23N=C(SC3)N)cc1': ['S(-C-C(-N)-C-C-C)-C',
#   'S(-C-C(-C)-N)-C',
#   'S(-C-C-N)-C',
#   'S(-C-C(-C)-C-C)-C',
#   'S(-C-C(-C)-C)-C',
#   'S(-C-C-C-C-C)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-N',
#   'S-C-C(-C)-C-C-C',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S1CC(N=C1N)(C)c1cc(NC(=O)c2ncccc2)ccc1': ['S(-C-C(-C)-N)-C',
#   'S(-C-C-N)-C',
#   'S(-C-C(-C)-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-N',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'Clc1ccc(nc1)C(=O)Nc1cc(ccc1)C12N=C(SCC1C2)N': ['S(-C-C(-C)-C-c1:c:c:c:c:c:1)-C',
#   'S(-C-C(-C)-C-C)-C',
#   'S(-C-C(-C)-C)-C',
#   'S(-C-C-C-C-N)-C',
#   'S(-C-C-C-C-C)-C',
#   'S(-C-C-C-c1:c:c:c:c:c:1)-C',
#   'S(-C-C-C-c:c:c:c:c)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-C-C(-N)-C',
#   'S-C-C-C-C-N',
#   'S-C-C-C-c1:c:c:c:c:c:1',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S(CC[C@H](NC(=O)[C@@H](NC(=O)C)CC(C)C)C(=O)N[C@H]([C@@H](O)C[C@H](C(=O)NCCCC)C)CC(C)C)C': ['S(-C-C-C-C-N-C-C)-C',
#   'S(-C-C-C-C-N-C)-C',
#   'S(-C-C-C-C-N)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-C-C-N-C',
#   'S-C-C-C-C-N',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S(CC[C@H](NC(=O)CCC(C)C)C(=O)N[C@H]([C@@H](O)C[C@H](C(=O)NCCCC)C)CC(C)C)C': ['S(-C-C-C-C-N-C-C)-C',
#   'S(-C-C-C-C-N-C)-C',
#   'S(-C-C-C-C-N)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-C-C-N-C',
#   'S-C-C-C-C-N',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S(CCC(NC(=O)C(NC(=O)C)C(C)C)C(=O)NC(C(O)CC(C(=O)NCCCC)C)CC(C)C)C': ['S(-C-C-C-C-N-C-C)-C',
#   'S(-C-C-C-C-N-C)-C',
#   'S(-C-C-C-C-N)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-C-C-N-C',
#   'S-C-C-C-C-N',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S(CCC(NC(=O)C(NC(=O)C)C)C(=O)NC(C(O)CC(C(=O)NCCCC)C)CC(C)C)C': ['S(-C-C-C-C-N-C-C)-C',
#   'S(-C-C-C-C-N-C)-C',
#   'S(-C-C-C-C-N)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-C-C-N-C',
#   'S-C-C-C-C-N',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S(C)C1CCC([NH2+]CC(O)C(NC(=O)C)Cc2cc(F)cc(F)c2)(CC1)c1cc(ccc1)C(C)(C)C': ['S(-C-C-C-C-N-C-C)-C',
#   'S(-C-C-C-C-N-C)-C',
#   'S(-C-C-C-C-N)-C',
#   'S(-C-C-C-C-C-C)-C',
#   'S(-C-C-C-C-C)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-C-C(-C)-N-C-C',
#   'S-C-C-C-C(-N)-C',
#   'S-C-C-C-C-N-C',
#   'S-C-C-C-C-N',
#   'S-C-C-C-C(-C)-C-C',
#   'S-C-C-C-C(-C)-C',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'Clc1cc(cc(F)c1)-c1cc2c(SC(CC23N=C(N)N(C)C3=O)(C)C)cc1': ['S(-C-C-C-C-N-C)-C',
#   'S(-C-C-C-C-N)-C',
#   'S(-C-C-C-c:c:c:c:c)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-C-C-N-C',
#   'S-C-C-C-C-N',
#   'S-C-C-C-c1:c:c:c:c:c:1',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S1c2c(cc(cc2)-c2cc(ccc2)C#N)C2(N=C(N)N(C)C2=O)CC1(C)C': ['S(-C-C-C-C-N-C)-C',
#   'S(-C-C-C-C-N)-C',
#   'S(-C-C-C-c:c:c:c:c)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-C-C-N-C',
#   'S-C-C-C-C-N',
#   'S-C-C-C-c1:c:c:c:c:c:1',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'Clc1ccc(nc1)C(=O)Nc1cc(ccc1)C12N=C(SCCC1C2)N': ['S(-C-C-C-C-N)-C',
#   'S(-C-C-C-C-C-c1:c:c:c:c:c:1)-C',
#   'S(-C-C-C-C-C-C)-C',
#   'S(-C-C-C-C-C)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-C-C(-N)-C',
#   'S-C-C-C-C-N',
#   'S-C-C-C-C(-C)-C',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S1CCC(N=C1N)(C)c1cc(ccc1)-c1cc(OC)ccc1': ['S(-C-C-C-c1:c:c:c:c:c:1)-C',
#   'S(-C-C-C-c:c:c:c:c)-C',
#   'S(-C-C-C-C)-C',
#   'S(-C-C-C)-C',
#   'S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C-C-c1:c:c:c:c:c:1',
#   'S-C-C-C-C',
#   'S-C-C-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'Clc1cc(ccc1OCCCC)CSC(=[NH2+])N': ['S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S(CC)c1cc(ccc1)-c1ccc(cc1)C1CC1C=1N=C(N)N(C)C(=O)C=1': ['S(-C-C)-C',
#   'S(-C)-C',
#   'S-C-C',
#   'S-C',
#   'S'],
#  'S(c1cc(cc(c1)C(=O)NC(Cc1cc(F)cc(F)c1)C(O)C[NH2+]Cc1cc(OC)ccc1)C(=O)N(CCC)CCC)c1ccccc1': ['S(-C)-C',
#   'S-C',
#   'S'],
#  'S(c1cc(cc(c1)C(=O)NC(Cc1cc(F)cc(F)c1)C(O)C[NH2+]Cc1cc(OC)ccc1)C(=O)N(CCC)CCC)c1ccc(OC)cc1': ['S(-C)-C',
#   'S-C',
#   'S'],
#  'S(C)c1cc(ccc1)-c1ccc(cc1)C1CC1C=1N=C(N)N(C)C(=O)C=1': ['S(-C)-C',
#   'S-C',
#   'S'],
#  'S(C)c1cc(ccc1)-c1cc2c(OC(CC23N=C(N)N(C)C3=O)(C)C)cc1': ['S(-C)-C',
#   'S-C',
#   'S'],
#  'S(Oc1cc(ccc1)C(=O)NC(Cc1ccccc1)C(O)C[NH2+]C(C(=O)NC1CCCCC1)C)(=O)(=O)Cc1ccccc1': ['S(-C-C)(=O)=O',
#   'S(-C)(=O)=O',
#   'S(-C-C)=O',
#   'S(-C)=O',
#   'S-C-C',
#   'S-C',
#   'S(=O)=O',
#   'S=O',
#   'S'],
#  'Clc1cc2CC(N=C(NC(Cc3cscc3CCC3CC3)C(=O)[O-])c2cc1)(C)C': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's
['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1ccnc1-c1cc(cc(F)c1)CC(NC(=O)COC)C(O)C[NH2+]C1CC2(Oc3ncc(cc13)CC(C)(C)C)CCC2': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1ccnc1-c1cc(ccc1)CC(NC(=O)C(O)C)C(O)C[NH2+]C1CC2(Oc3ncc(cc13)CC(C)(C)C)CCC2': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1ccnc1-c1cc(ccc1)CC(NC(=O)C)C(O)C[NH2+]C1CC2(Oc3ncc(cc13)CC(C)(C)C)CCC2': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1ccnc1-c1cc(ccc1)CC(NC(=O)COC)C(O)C[NH2+]C1CC2(Oc3ncc(cc13)CC(C)(C)C)CCC2': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1cc(nc1-c1cc(ccc1)CC(NC(=O)COC)C(O)C[NH2+]C1CC2(Oc3ncc(cc13)CC(C)(C)C)CCC2)C': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1ccnc1-c1cc(ccc1)CC(NC(=O)COCC)C(O)C[NH2+]C1CC2(Oc3ncc(cc13)CC(C)(C)C)CCC2': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1ccnc1-c1cc(ccc1F)CC(NC(=O)COC)C(O)C[NH2+]C1CC2(Oc3ncc(cc13)CC(C)(C)C)CCC2': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1ccnc1-c1cc(ccc1)CC(NC(=O)[C@@H](OC)C)C(O)C[NH2+]C1CC2(Oc3ncc(cc13)CC(C)(C)C)CCC2': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1ccnc1-c1cc(CC(NC(=O)COC)C(O)C[NH2+]C2CC3(Oc4ncc(cc24)CC(C)(C)C)CCC3)c(F)cc1': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1ccnc1-c1cc(ccc1)CC(NC(=O)C(OC)OC)C(O)C[NH2+]C1CC2(Oc3ncc(cc13)CC(C)(C)C)CCC2': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1ccnc1-c1cc(ccc1)CC(NC(=O)CC)C(O)C[NH2+]C1CC2(Oc3ncc(cc13)CC(C)(C)C)CCC2': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1ccnc1-c1cc(ccc1)CC(NC(=O)C(OCC)C)C(O)C[NH2+]C1CC2(Oc3ncc(cc13)CC(C)(C)C)CCC2': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  's1ccnc1-c1cccc(CC(NC(=O)COC)C(O)C[NH2+]C2CC3(Oc4ncc(cc24)CC(C)(C)C)CCC3)c1F': ['s(:c:c):c',
#   's(:c):c',
#   's:c:c',
#   's:c',
#   'S'],
#  'Clc1cc(cc(C)c1NC(=O)C)CN\\C(=N/C(=O)c1c(nsc1C)-c1ccc(OC)cc1)\\N': ['s:c:c',
#   's:c',
#   'S'],
#  'Clc1cc(cc(Cl)c1N)CN\\C(=N/C(=O)c1c(nsc1C)-c1ccc(OC)cc1)\\N': ['s:c:c',
#   's:c',
#   'S']}

# %%
list(results_transformed.values())[0].shape
# Out:
# (361,)

# %%
X_train = np.array(list(results_transformed.values()))
X_test = np.array(list(test_results_transformed.values()))

X_train.shape
# Out:
# (380, 361)

# %%
len(y_train)
# Out:
# 380

# %%
(X_train.shape, len(y_train))
# Out:
# ((380, 361), 380)

# %%
(X_test.shape, len(y_test))
# Out:
# ((109, 361), 109)

# %% [markdown]
# #

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

clf = RandomForestClassifier(random_state=0)
clf.fit(X_train, y_train)

y_pred = clf.predict_proba(X_test)[:, 1]
auroc = roc_auc_score(y_test, y_pred)

print(f"AUROC: {auroc:.2%}")
# Out:
# AUROC: 41.40%
