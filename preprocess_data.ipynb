# %%
import pandas as pd

df = pd.read_csv("moleculenet/delaney-processed.csv")
df.head()
# Out:
#   Compound ID  ESOL predicted log solubility in mols per litre  \
# 0   Amigdalin                                           -0.974
# 1    Fenfuram                                           -2.885
# 2      citral                                           -2.579
# 3      Picene                                           -6.618
# 4   Thiophene                                           -2.232
#
#    Minimum Degree  Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# 0               1           457.432                        7                3
# 1               1           201.225                        1                2
# 2               1           152.237                        0                0
# 3               2           278.354                        0                5
# 4               2            84.143                        0                1
#
#    Number of Rotatable Bonds  Polar Surface Area  \
# 0                          7              202.32
# ...

# %%
list(enumerate(df.columns))
# Out:
# [(0, 'Compound ID'),
#  (1, 'ESOL predicted log solubility in mols per litre'),
#  (2, 'Minimum Degree'),
#  (3, 'Molecular Weight'),
#  (4, 'Number of H-Bond Donors'),
#  (5, 'Number of Rings'),
#  (6, 'Number of Rotatable Bonds'),
#  (7, 'Polar Surface Area'),
#  (8, 'measured log solubility in mols per litre'),
#  (9, 'smiles')]

# %%
df = df.iloc[:, [0, 9]]
df.columns = ["id", "desc"]
df["value"] = 0
df = df[["id", "value", "desc"]]
df
# Out:
#                   id  value                                               desc
# 0          Amigdalin      0  OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...
# 1           Fenfuram      0                             Cc1occc1C(=O)Nc2ccccc2
# 2             citral      0                               CC(C)=CCCC(C)=CC(=O)
# 3             Picene      0                 c1ccc2c(c1)ccc3c2ccc4c5ccccc5ccc43
# 4          Thiophene      0                                            c1ccsc1
# ...              ...    ...                                                ...
# 1123       halothane      0                                   FC(F)(F)C(Cl)Br
# 1124          Oxamyl      0                          CNC(=O)ON=C(SC)C(=O)N(C)C
# 1125       Thiometon      0                                  CCSCCSP(=S)(OC)OC
# 1126  2-Methylbutane      0                                            CCC(C)C
# 1127        Stirofos      0              COP(=O)(OC)OC(=CCl)c1cc(Cl)c(Cl)cc1Cl
#
# [1128 rows x 3 columns]

# %%
df.to_csv("moleculenet/new_processed_data.csv", index=False)
